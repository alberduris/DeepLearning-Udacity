# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data
  
words = read_data(filename)
print('Data size %d' % len(words))
print('Pick a random example "%s"' % words[np.random.randint(len(words))])
# Out:
# Data size 17005207
# Pick a random example "so"

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000 #Queremos almacenar las 50.000 palabras más comunes

'''
Contar las palabras más comunes

'''
def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    print('Las primeras palabras más comunes:\n',count[0:5])
    
    print('Creando un diccionario {"PalabraComun":"NumOcurrencias"}')
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    print('Diccionario creado\n')
        
    print('Creando:\nData:Lista nº de ocurrencias\nCount:Lista con par palabra-numOcurrencia\nDictionary\nReverse Dictionary\n')
    data = list()
    unk_count = 0
    '''
    Por cada palabra del corpus
     + Si es está en el diccionario de palabras comunes -> Almacenar su nº de ocurrencia en 'index'
     + Si no, almacenar 0 en 'index' y añadir 1 al contador de palabras "desconocidas"
     
    Actualizar el contador en 'Count'
    Crear diccionario inverso
    '''
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
    
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
print('Example Dictionary',dictionary['inductor'])
print('Exmaple Reverse dictionary',reverse_dictionary[19348])
del words  # Hint to reduce memory.
# Out:
# Las primeras palabras más comunes:
#  [['UNK', -1], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Creando un diccionario {"PalabraComun":"NumOcurrencias"}
# Diccionario creado
#
# Creando:
# Data:Lista nº de ocurrencias
# Count:Lista con par palabra-numOcurrencia
# Dictionary
# Reverse Dictionary
#
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5244, 3082, 12, 6, 195, 2, 3136, 46, 59, 156]
# Example Dictionary 19348
# Exmaple Reverse dictionary inductor

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'term', 'a', 'anarchism', 'of', 'term', 'originated', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Variables.
    embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.036750
# Nearest to system: gluon, identifiable, sakai, oop, alga, turismo, geirr, enclosing,
# Nearest to two: vdash, minister, bankrupt, staple, filamentous, desert, debates, shooting,
# Nearest to or: incite, joystick, arion, taiwanese, boutique, deserves, mab, leftism,
# Nearest to some: pr, stipulates, artemis, administrative, debating, gulliver, villeneuve, valkyrie,
# Nearest to other: sulfate, evading, akihabara, papua, confirming, riverview, scream, gorton,
# Nearest to while: graceful, ccg, ecstatic, inability, rachmaninoff, applies, freestyle, navarro,
# Nearest to has: breatharian, angst, profiled, geelong, wallenberg, governorate, hathaway, oppressors,
# Nearest to into: ai, pu, candy, aleksandr, basutoland, arthropod, lia, mellor,
# Nearest to when: intermixed, quantifying, embroidered, replay, negotiating, showings, elrond, explication,
# Nearest to used: timor, icaza, outputting, marangella, oratorios, ivan, laid, eternal,
# Nearest to known: massed, substituted, dolly, heartbroken, montrose, fin, raids, mohammad,
# Nearest to this: mj, secure, glu, tocharians, landholdings, deceptive, sundance, peterson,
# Nearest to however: touching, arms, coughing, raping, fragmented, debasement, peculiarities, dealing,
# Nearest to up: functional, selectively, lecturing, novello, dyes, xxxvii, thermal, woodrow,
# Nearest to american: kokhba, osage, trembling, acknowledged, mojito, jockey, zanu, dorsal,
# Nearest to four: radians, memphis, torrents, fadh, lass, lansdowne, deputies, speght,
# Average loss at step 2000: 4.383819
# Average loss at step 4000: 3.965597
# Average loss at step 6000: 3.829363
# Average loss at step 8000: 3.751336
# Average loss at step 10000: 3.681952
# Nearest to system: gluon, identifiable, geirr, qing, mime, peg, honours, modula,
# Nearest to two: five, three, eight, six, seven, one, four, nine,
# Nearest to or: and, laptops, archbishopric, shower, kinross, bartolomeo, toba, aesop,
# Nearest to some: many, villeneuve, progresses, these, their, writes, its, clayton,
# Nearest to other: sulfate, undoubtedly, papua, riverview, defines, structure, outlawing, cigarette,
# Nearest to while: rachmaninoff, graceful, ecstatic, chobert, maynooth, background, navarro, redirected,
# Nearest to has: was, had, is, have, conductive, spun, angst, representing,
# Nearest to into: bombers, bushman, from, arthropod, tomcat, ai, operationally, pu,
# Nearest to when: became, if, quantifying, practitioner, vorkosigan, negotiating, inspire, ncipe,
# Nearest to used: icaza, outputting, timor, known, australopithecus, laid, wiping, vlaanderen,
# Nearest to known: raids, ona, used, well, azo, unfounded, ghent, ip,
# Nearest to this: it, that, the, haitians, which, secure, performance, contradicts,
# Nearest to however: that, bras, but, platinum, sharply, touching, planting, malaya,
# Nearest to up: according, functional, out, stalling, woodrow, koreans, lithographs, alcindor,
# Nearest to american: rendezvous, zanu, suggestive, lovin, bridges, pythagoreans, mojito, guildhall,
# Nearest to four: five, three, eight, six, seven, zero, nine, two,
# Average loss at step 12000: 3.624460
# Average loss at step 14000: 3.666394
# Average loss at step 16000: 3.543902
# Average loss at step 18000: 3.586487
# Average loss at step 20000: 3.469273
# Nearest to system: peg, gluon, davao, identifiable, honours, geirr, tel, sakai,
# Nearest to two: three, five, six, four, seven, one, zero, eight,
# Nearest to or: and, than, unspecific, dignity, partners, acoustics, for, leftism,
# Nearest to some: many, these, all, several, their, its, most, progresses,
# Nearest to other: several, different, stooges, many, their, callet, some, utterly,
# Nearest to while: were, chobert, are, but, maynooth, background, wiccan, karamanlis,
# Nearest to has: had, have, was, is, spun, tagline, antoine, troilus,
# Nearest to into: from, arthropod, on, operationally, by, bushman, enzyme, ai,
# Nearest to when: if, where, after, before, became, vorkosigan, by, phagspa,
# Nearest to used: known, outputting, able, icaza, available, australopithecus, lau, vlaanderen,
# Nearest to known: used, such, raids, well, ona, regarded, azo, tutored,
# Nearest to this: it, which, that, the, viva, mistakenly, there, tombalbaye,
# Nearest to however: but, that, platinum, ap, malaya, bras, stamford, jaguar,
# Nearest to up: out, according, them, retreat, entrepreneurs, multi, stereotypically, lithographs,
# Nearest to american: fencer, phrygian, relena, british, drew, australian, rendezvous, bridges,
# Nearest to four: five, three, six, seven, eight, two, zero, nine,
# Average loss at step 22000: 3.545722
# Average loss at step 24000: 3.526098
# Average loss at step 26000: 3.510519
# Average loss at step 28000: 3.496457
# Average loss at step 30000: 3.515190
# Nearest to system: peg, systems, gluon, representing, spivak, tel, mime, davao,
# Nearest to two: three, four, five, six, eight, seven, one, zero,
# Nearest to or: and, than, aesop, phenomena, but, lindh, eca, mesoplodon,
# Nearest to some: many, all, these, several, their, other, such, most,
# Nearest to other: some, many, several, different, stooges, european, others, all,
# Nearest to while: when, maynooth, were, are, however, chobert, but, salutation,
# Nearest to has: had, have, was, is, returner, tagline, justify, kio,
# Nearest to into: from, operationally, bombers, with, bushman, pu, enzyme, tomcat,
# Nearest to when: if, where, after, while, before, during, although, took,
# Nearest to used: known, able, available, called, treated, defined, considered, australopithecus,
# Nearest to known: used, such, regarded, ona, well, tutored, described, raids,
# Nearest to this: it, which, that, the, polyhedron, any, what, every,
# Nearest to however: but, that, ap, while, which, although, where, abandon,
# Nearest to up: out, them, devaluation, according, off, entrepreneurs, xxxvii, multi,
# Nearest to american: suggestive, indian, british, australian, italian, phrygian, international, zanu,
# Nearest to four: five, six, seven, eight, three, nine, two, zero,
# Average loss at step 32000: 3.432974
# Average loss at step 34000: 3.404203
# Average loss at step 36000: 3.465911
# Average loss at step 38000: 3.461510
# Average loss at step 40000: 3.453136
# Nearest to system: systems, method, representing, peg, spivak, davao, nullified, mime,
# Nearest to two: three, four, six, five, eight, one, seven, zero,
# Nearest to or: and, than, limericks, aesop, antisocial, unspecific, dromedary, ravaged,
# Nearest to some: many, several, these, all, their, most, the, any,
# Nearest to other: various, several, different, deliberation, including, many, utterly, callet,
# Nearest to while: although, when, maynooth, though, salutation, are, however, before,
# Nearest to has: had, have, is, was, darkly, chiba, since, pronouncement,
# Nearest to into: from, through, over, arthropod, bombers, enzyme, between, concessions,
# Nearest to when: if, where, after, during, before, although, while, was,
# Nearest to used: known, defined, called, treated, available, australopithecus, mentioned, seen,
# Nearest to known: used, regarded, such, ona, described, tutored, mentioned, inherited,
# Nearest to this: it, which, the, sumter, what, he, some, there,
# Nearest to however: but, that, although, ap, if, where, should, while,
# Nearest to up: out, them, off, devaluation, him, entrepreneurs, supra, curries,
# Nearest to american: english, british, italian, indian, australian, phrygian, international, suggestive,
# Nearest to four: six, five, eight, seven, three, nine, two, zero,
# Average loss at step 42000: 3.448704
# Average loss at step 44000: 3.424860
# Average loss at step 46000: 3.366041
# Average loss at step 48000: 3.338188
# Average loss at step 50000: 3.393557
# Nearest to system: systems, representing, peg, method, spivak, technology, techniques, pratt,
# Nearest to two: four, three, six, five, seven, one, eight, nine,
# Nearest to or: and, than, but, disabling, phenylalanine, wends, eca, eyeball,
# Nearest to some: many, several, these, all, most, various, their, both,
# Nearest to other: various, different, belvedere, remaining, deliberation, britannia, judges, walruses,
# Nearest to while: although, however, when, though, maynooth, before, vainly, were,
# Nearest to has: had, have, is, was, tagline, darkly, since, schumpeter,
# Nearest to into: from, through, over, within, on, medicinal, across, back,
# Nearest to when: if, where, before, after, while, during, although, with,
# Nearest to used: known, available, seen, considered, defined, written, mentioned, found,
# Nearest to known: used, regarded, such, ona, recognized, described, inherited, tutored,
# Nearest to this: which, it, what, that, the, judean, there, any,
# Nearest to however: but, although, while, though, that, ap, if, intertwined,
# Nearest to up: out, them, off, him, polities, down, devaluation, curries,
# Nearest to american: italian, british, indian, english, phrygian, international, relena, australian,
# Nearest to four: six, seven, eight, five, three, nine, two, zero,
# Average loss at step 52000: 3.321317
# Average loss at step 54000: 3.351045
# Average loss at step 56000: 3.396029
# Average loss at step 58000: 3.284790
# Average loss at step 60000: 3.426289
# Nearest to system: systems, technology, peg, representing, lethargy, larmor, method, program,
# Nearest to two: three, six, seven, eight, five, one, four, zero,
# Nearest to or: and, than, eca, but, nonce, manually, muller, antisocial,
# Nearest to some: many, several, these, all, this, their, various, any,
# Nearest to other: various, many, different, several, deliberation, including, remaining, these,
# Nearest to while: although, when, before, however, though, signifying, maynooth, if,
# Nearest to has: had, have, was, is, since, strangeness, chiba, resigns,
# Nearest to into: from, through, over, between, clausius, within, arthropod, paran,
# Nearest to when: if, where, before, while, after, although, during, was,
# Nearest to used: known, seen, available, defined, viewed, able, considered, found,
# Nearest to known: regarded, used, such, described, recognized, ona, well, inherited,
# Nearest to this: which, it, the, what, some, that, another, our,
# Nearest to however: but, although, though, that, while, when, which, estrada,
# Nearest to up: out, off, them, down, polities, him, supra, devaluation,
# Nearest to american: british, australian, italian, english, international, phrygian, canadian, indian,
# Nearest to four: six, five, three, eight, seven, nine, two, zero,
# Average loss at step 62000: 3.392689
# Average loss at step 64000: 3.375699
# Average loss at step 66000: 3.242975
# Average loss at step 68000: 3.343828
# Average loss at step 70000: 3.382367
# Nearest to system: systems, technology, principals, peg, program, method, representing, tel,
# Nearest to two: three, one, five, six, four, seven, eight, zero,
# Nearest to or: and, than, xenophon, mesoplodon, dignity, uniformitarianism, melts, aspire,
# Nearest to some: many, several, these, all, most, any, their, various,
# Nearest to other: various, different, including, many, these, some, fifty, remaining,
# Nearest to while: although, when, though, before, however, signifying, if, where,
# Nearest to has: had, have, was, is, contains, schumpeter, since, flunitrazepam,
# Nearest to into: through, from, within, over, medicinal, sprite, enzyme, eurostar,
# Nearest to when: if, where, while, after, although, before, during, though,
# Nearest to used: known, seen, defined, considered, available, described, viewed, mentioned,
# Nearest to known: used, regarded, such, recognized, described, considered, defined, australopithecus,
# Nearest to this: it, which, another, what, overworld, that, some, the,
# Nearest to however: but, although, though, that, while, since, and, which,
# Nearest to up: out, off, them, down, him, supra, back, polities,
# Nearest to american: british, australian, italian, african, international, indian, phrygian, canadian,
# Nearest to four: six, five, eight, seven, three, nine, zero, two,
# Average loss at step 72000: 3.401446
# Average loss at step 74000: 3.407481
# Average loss at step 76000: 3.392082
# Average loss at step 78000: 3.365278
# Average loss at step 80000: 3.260440
# Nearest to system: systems, technology, peg, spivak, nullified, bilirubin, mime, tel,
# Nearest to two: four, six, three, five, one, seven, eight, nine,
# Nearest to or: and, than, mandaeans, without, antisocial, alienation, hygiene, nomads,
# Nearest to some: many, several, these, all, certain, most, both, various,
# Nearest to other: various, including, different, remaining, several, many, these, deliberation,
# Nearest to while: when, although, though, before, after, where, andante, without,
# Nearest to has: had, have, is, was, schumpeter, having, since, chiba,
# Nearest to into: through, from, within, across, back, on, over, off,
# Nearest to when: if, where, while, although, after, before, during, though,
# Nearest to used: known, seen, available, found, considered, described, able, mentioned,
# Nearest to known: used, regarded, recognized, such, described, considered, cited, australopithecus,
# Nearest to this: which, it, that, judean, what, another, the, some,
# Nearest to however: but, although, though, when, that, since, where, voiceover,
# Nearest to up: down, off, out, them, back, him, polities, supra,
# Nearest to american: british, italian, australian, african, indian, canadian, phrygian, english,
# Nearest to four: six, five, three, eight, seven, two, nine, zero,
# Average loss at step 82000: 3.339445
# Average loss at step 84000: 3.392216
# Average loss at step 86000: 3.325974
# Average loss at step 88000: 3.317499
# Average loss at step 90000: 3.342730
# Nearest to system: systems, technology, peg, network, mime, method, techniques, tel,
# Nearest to two: three, five, six, four, seven, eight, one, nine,
# Nearest to or: and, than, while, mandaeans, wahhabism, camacho, tintin, princesses,
# Nearest to some: many, several, these, various, all, both, certain, most,
# Nearest to other: various, different, remaining, some, older, including, many, batavian,
# Nearest to while: although, when, though, before, where, after, if, or,
# Nearest to has: had, have, was, is, contains, having, since, chiba,
# Nearest to into: through, from, across, over, back, within, radioisotope, enzyme,
# Nearest to when: if, where, while, after, before, although, during, since,
# Nearest to used: known, seen, available, intended, treated, regarded, considered, mentioned,
# Nearest to known: used, regarded, recognized, such, cited, described, considered, australopithecus,
# Nearest to this: it, which, another, judean, any, some, what, the,
# Nearest to however: but, although, though, that, since, especially, there, when,
# Nearest to up: off, down, out, back, them, supra, him, devaluation,
# Nearest to american: italian, british, australian, indian, canadian, german, english, french,
# Nearest to four: eight, five, six, seven, three, nine, zero, two,
# Average loss at step 92000: 3.342831
# Average loss at step 94000: 3.376242
# Average loss at step 96000: 3.352984
# Average loss at step 98000: 3.324813
# Average loss at step 100000: 3.203849
# Nearest to system: systems, network, technology, peg, inductor, escort, mime, method,
# Nearest to two: three, seven, six, five, four, eight, one, nine,
# Nearest to or: and, than, while, codebreaking, antisocial, civilis, m, philologists,
# Nearest to some: many, several, these, most, both, various, all, any,
# Nearest to other: various, including, older, userland, different, several, many, remaining,
# Nearest to while: although, when, though, before, if, including, after, where,
# Nearest to has: had, have, is, was, contains, chiba, since, avesta,
# Nearest to into: through, from, across, within, over, enzyme, off, back,
# Nearest to when: if, while, although, where, before, after, however, though,
# Nearest to used: known, intended, available, found, designed, responsible, defined, described,
# Nearest to known: regarded, used, recognized, cited, such, described, called, defined,
# Nearest to this: which, it, another, judean, some, that, the, what,
# Nearest to however: but, although, though, when, since, there, if, touches,
# Nearest to up: off, down, out, back, them, together, him, polities,
# Nearest to american: british, indian, italian, canadian, australian, french, english, european,
# Nearest to four: three, five, seven, six, eight, nine, two, zero,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                       ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, bag_window):
    global data_index
    span = 2 * bag_window + 1 # [ bag_window target bag_window ]
    batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)  
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size):
        # just for testing
        buffer_list = list(buffer)
        labels[i, 0] = buffer_list.pop(bag_window)
        batch[i] = buffer_list
        # iterate to the next buffer
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:16]])

for bag_window in [1, 2]:
    data_index = 0
    batch, labels = generate_batch(batch_size=4, bag_window=bag_window)
    print('\nwith bag_window = %d:' % (bag_window))  
    print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])  
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
# with bag_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#     labels: ['originated', 'as', 'a', 'term']
#
# with bag_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
#     labels: ['as', 'a', 'term', 'of']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
###skip_window = 1 # How many words to consider left and right.
###num_skips = 2 # How many times to reuse an input to generate a label.
bag_window = 2 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window * 2])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Variables.
    embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Model.
    # Look up embeddings for inputs.
    embeds = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=tf.reduce_sum(embeds, 1),
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(
          batch_size, bag_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.287996
# Nearest to all: conduit, dyck, tar, detainees, plague, dances, osborn, gutierrez,
# Nearest to his: elaine, overloading, headmaster, shrouded, fairway, inversion, leptons, generalizes,
# Nearest to however: hygienic, cologne, bierce, pcc, capsules, selfishness, morocco, dachshund,
# Nearest to known: equilibrium, fingertips, guevara, extraneous, emir, fired, alphabetic, wisc,
# Nearest to they: valencian, rulings, voiceless, facet, uplink, eruptions, edmund, liberate,
# Nearest to state: porfirio, injectors, blackbird, mcdowell, capoeira, arid, nationalisation, ethnology,
# Nearest to in: kush, analects, transportation, aerobic, barracuda, illogical, promontory, followings,
# Nearest to UNK: shielding, davidians, mayonnaise, cutaway, trichechus, literary, linnaean, renders,
# Nearest to been: senatorial, coil, laminated, disguising, blown, cumberland, curtail, mov,
# Nearest to most: exile, coveted, strumming, deceptive, everyone, beverley, ecclesiasticus, offense,
# Nearest to who: caeiro, income, theseus, androgen, melodramatic, pao, concerts, eug,
# Nearest to by: streaks, bundaberg, modes, unresponsive, genuinely, midway, birkenau, shem,
# Nearest to such: fulvia, proceeding, abdicate, tabloid, moss, tricyclic, lawfully, pca,
# Nearest to have: stain, dismounted, unbundling, sustains, georgia, je, tammy, ppg,
# Nearest to there: metres, mordechai, achieve, driscoll, pawns, ravalomanana, whisper, basayev,
# Nearest to is: esperantists, brutally, colloid, hydrocarbons, reminding, cbt, progressing, utraquists,
# Average loss at step 2000: 4.580314
# Average loss at step 4000: 3.942048
# Average loss at step 6000: 3.720707
# Average loss at step 8000: 3.526826
# Average loss at step 10000: 3.483502
# Nearest to all: those, many, artwork, conduit, pagerank, some, spamming, tlatoani,
# Nearest to his: their, her, the, its, attractions, husky, bartle, draining,
# Nearest to however: deceived, livius, planners, ottawa, yusuf, lammas, whiskey, hollis,
# Nearest to known: such, used, isomorphic, guevara, none, saracens, romeo, riders,
# Nearest to they: he, we, there, it, jirga, spinoffs, sedatives, i,
# Nearest to state: majdanek, professionals, square, lifeboats, renamed, blackout, monarchists, induce,
# Nearest to in: on, during, democracies, competed, where, until, keswick, humours,
# Nearest to UNK: sony, tea, gazelle, protestantism, meisner, vilhelm, ringed, verisimilitude,
# Nearest to been: mkultra, bovine, joram, monogatari, become, scud, hints, amused,
# Nearest to most: many, more, some, ink, exchangeable, ripley, premiums, amok,
# Nearest to who: he, simulator, which, repositories, surah, nejd, sicily, deck,
# Nearest to by: shem, subvert, kassites, strangeness, lambda, moraines, appomattox, considerably,
# Nearest to such: well, icc, known, maneuvered, regarded, rehoboam, surpasses, progression,
# Nearest to have: has, had, be, secretariat, cray, lighting, sloti, pronounce,
# Nearest to there: it, they, predicates, tin, brava, supervisory, outnumbered, voroshilov,
# Nearest to is: was, are, were, became, has, contracts, capo, rockin,
# Average loss at step 12000: 3.486814
# Average loss at step 14000: 3.424865
# Average loss at step 16000: 3.442820
# Average loss at step 18000: 3.411025
# Average loss at step 20000: 3.221613
# Nearest to all: several, both, many, various, tramp, shasta, hendrix, bollywood,
# Nearest to his: their, her, its, s, the, my, our, your,
# Nearest to however: although, but, though, that, if, when, deceived, shrapnel,
# Nearest to known: used, referred, regarded, considered, isomorphic, such, served, described,
# Nearest to they: we, you, he, these, there, she, i, absorbs,
# Nearest to state: government, pissarro, induce, cider, tfl, commandants, program, square,
# Nearest to in: during, within, since, throughout, through, until, on, tablet,
# Nearest to UNK: autopsy, english, david, satisfactory, cabbage, picnics, undetected, french,
# Nearest to been: become, already, mkultra, monogatari, was, bovine, be, precincts,
# Nearest to most: more, some, many, entire, very, ripley, uomo, keeping,
# Nearest to who: which, he, she, that, nun, complained, nejd, expecting,
# Nearest to by: interdisciplinarity, tremble, strangeness, bloomington, maxine, with, shem, kouchner,
# Nearest to such: well, regarded, described, known, maneuvered, result, far, icc,
# Nearest to have: had, has, having, are, be, secretariat, alert, were,
# Nearest to there: they, called, longer, taro, bresson, given, brunel, predicates,
# Nearest to is: was, are, became, were, has, being, becomes, does,
# Average loss at step 22000: 3.359942
# Average loss at step 24000: 3.288237
# Average loss at step 26000: 3.255900
# Average loss at step 28000: 3.290971
# Average loss at step 30000: 3.225525
# Nearest to all: many, various, some, both, every, those, ippon, any,
# Nearest to his: her, their, its, my, s, the, your, our,
# Nearest to however: though, although, because, since, but, until, carbine, calculi,
# Nearest to known: referred, regarded, used, available, seen, such, considered, described,
# Nearest to they: we, you, there, he, she, these, imr, linux,
# Nearest to state: government, parliament, program, actions, induce, pissarro, city, hunyadi,
# Nearest to in: within, throughout, since, on, of, during, around, among,
# Nearest to UNK: meisner, et, dr, verisimilitude, polling, crucifix, protestantism, der,
# Nearest to been: become, mkultra, come, be, scud, were, occurred, was,
# Nearest to most: many, some, cesare, uomo, more, carrots, ripley, all,
# Nearest to who: holomorphic, that, like, organising, young, he, leakey, northumbrian,
# Nearest to by: under, equivalents, maxine, taos, interdisciplinarity, through, collectivist, edifices,
# Nearest to such: well, result, regarded, far, dialing, known, seen, described,
# Nearest to have: has, had, having, allow, include, are, produce, secretariat,
# Nearest to there: they, it, considered, basses, jebel, she, sometimes, solidify,
# Nearest to is: was, are, became, has, makes, becomes, were, nasals,
# Average loss at step 32000: 3.006556
# Average loss at step 34000: 3.200835
# Average loss at step 36000: 3.188635
# Average loss at step 38000: 3.163374
# Average loss at step 40000: 3.155673
# Nearest to all: many, several, various, some, every, resolving, mee, alam,
# Nearest to his: her, their, its, your, our, my, the, startled,
# Nearest to however: although, though, that, since, but, while, and, until,
# Nearest to known: referred, regarded, used, described, seen, available, translated, considered,
# Nearest to they: we, you, outrun, he, statist, bitterness, golem, there,
# Nearest to state: nicolau, city, government, dalriada, equitable, states, parliament, pissarro,
# Nearest to in: during, within, since, on, throughout, after, where, around,
# Nearest to UNK: fittest, renouf, denoted, galloping, harding, devry, hipper, quarrelled,
# Nearest to been: become, occurred, entertained, be, was, begun, already, scud,
# Nearest to most: more, less, some, many, uomo, very, engineered, among,
# Nearest to who: which, he, handshake, elle, disinfectant, invocations, usually, tba,
# Nearest to by: when, interdisciplinarity, using, jozef, collectivist, stoney, technicality, vegetal,
# Nearest to such: well, result, follows, regarded, far, seen, described, classified,
# Nearest to have: had, has, having, secretariat, contain, offer, include, are,
# Nearest to there: it, considered, longer, driscoll, she, kinnear, they, ruptured,
# Nearest to is: was, became, are, has, becomes, includes, remains, makes,
# Average loss at step 42000: 3.207824
# Average loss at step 44000: 3.141634
# Average loss at step 46000: 3.134996
# Average loss at step 48000: 3.055220
# Average loss at step 50000: 3.060518
# Nearest to all: many, various, several, these, some, both, every, sampa,
# Nearest to his: her, their, its, our, my, your, s, the,
# Nearest to however: although, though, but, which, since, that, provers, where,
# Nearest to known: referred, regarded, used, described, available, seen, served, such,
# Nearest to they: we, you, he, there, she, kristofferson, imr, jirga,
# Nearest to state: government, city, induce, parliament, jud, actions, purchasing, statehood,
# Nearest to in: during, throughout, within, around, redstone, on, from, when,
# Nearest to UNK: beatrix, le, demarcation, der, fatty, hydro, beetles, jinnah,
# Nearest to been: become, already, occurred, remained, begun, numerous, amused, yacc,
# Nearest to most: many, more, cesare, less, among, uomo, several, especially,
# Nearest to who: which, surah, modernisation, plutonic, mischievous, louisville, exceeded, already,
# Nearest to by: interdisciplinarity, jozef, drake, lausanne, through, geniuses, lw, maxine,
# Nearest to such: well, follows, known, seen, result, described, simulates, regarded,
# Nearest to have: has, had, having, produce, contain, require, offer, were,
# Nearest to there: they, it, longer, considered, supervisory, soaemias, kinnear, sequenced,
# Nearest to is: was, are, became, has, makes, remains, contains, becomes,
# Average loss at step 52000: 3.101272
# Average loss at step 54000: 3.096802
# Average loss at step 56000: 2.918552
# Average loss at step 58000: 3.033952
# Average loss at step 60000: 3.044640
# Nearest to all: many, various, several, some, both, certain, these, every,
# Nearest to his: her, their, its, s, my, the, our, your,
# Nearest to however: although, though, but, while, that, debbie, preprocessing, mahogany,
# Nearest to known: referred, used, regarded, seen, defined, described, served, opposed,
# Nearest to they: we, you, he, she, there, imr, players, accomplices,
# Nearest to state: government, suvs, city, statehood, hunyadi, current, specialized, yeni,
# Nearest to in: within, during, throughout, since, among, on, at, until,
# Nearest to UNK: rousseau, dunstan, r, terse, harpsichord, motif, lyman, denounce,
# Nearest to been: become, occurred, existed, already, come, remained, begun, chaco,
# Nearest to most: some, more, especially, particularly, many, best, very, all,
# Nearest to who: he, louisville, which, modernisation, typically, whom, that, bogside,
# Nearest to by: subvert, interdisciplinarity, under, collectivist, thus, octavius, tobit, maxine,
# Nearest to such: well, follows, iho, regarded, result, classified, seen, simulates,
# Nearest to have: had, has, having, produce, contain, require, offer, include,
# Nearest to there: they, longer, it, kinnear, considered, mixed, called, these,
# Nearest to is: was, are, becomes, makes, has, remains, contains, includes,
# Average loss at step 62000: 3.017747
# Average loss at step 64000: 2.925512
# Average loss at step 66000: 2.939081
# Average loss at step 68000: 2.963930
# Average loss at step 70000: 3.006920
# Nearest to all: many, both, various, several, some, certain, future, every,
# Nearest to his: their, its, her, my, s, our, your, the,
# Nearest to however: although, but, though, because, while, when, that, whereas,
# Nearest to known: referred, regarded, described, defined, opposed, possible, served, used,
# Nearest to they: we, you, he, there, imr, cerebrospinal, impressively, dante,
# Nearest to state: government, city, nicolau, square, bayou, justice, knossos, adad,
# Nearest to in: within, throughout, during, since, on, around, at, gulfs,
# Nearest to UNK: animaniacs, commendation, vogt, afrobeat, devry, delinquency, curried, jordanian,
# Nearest to been: become, occurred, existed, come, appeared, remained, was, begun,
# Nearest to most: many, more, some, several, particularly, all, especially, earliest,
# Nearest to who: young, he, which, pulley, that, equinoxes, snowfalls, modernisation,
# Nearest to by: when, interdisciplinarity, subvert, jozef, octavius, without, fostering, lw,
# Nearest to such: well, follows, result, classified, seen, simulates, opposed, known,
# Nearest to have: had, has, having, contain, include, require, produce, allow,
# Nearest to there: longer, they, called, still, supervisory, available, hospitality, wagons,
# Nearest to is: was, are, makes, remains, becomes, became, includes, exists,
# Average loss at step 72000: 2.941929
# Average loss at step 74000: 2.868719
# Average loss at step 76000: 2.995863
# Average loss at step 78000: 3.007632
# Average loss at step 80000: 2.845397
# Nearest to all: many, various, any, both, every, some, certain, always,
# Nearest to his: their, her, its, your, my, the, s, our,
# Nearest to however: although, though, but, while, shorten, despite, because, whereas,
# Nearest to known: referred, regarded, opposed, used, described, served, possible, seen,
# Nearest to they: we, you, there, he, she, unmodified, others, kampaku,
# Nearest to state: government, justice, suvs, hunyadi, palestine, nicolau, containment, territory,
# Nearest to in: during, within, throughout, on, under, via, among, including,
# Nearest to UNK: zi, das, r, exeter, es, thea, arcueil, mpls,
# Nearest to been: become, occurred, appeared, come, begun, resulted, fallen, remained,
# Nearest to most: many, more, particularly, some, less, largest, all, greatest,
# Nearest to who: whom, lemass, modernisation, he, louisville, whose, typically, young,
# Nearest to by: interdisciplinarity, maxine, mayday, subvert, mortem, jozef, stravinsky, when,
# Nearest to such: well, seen, opposed, follows, described, result, regarded, simulates,
# Nearest to have: had, has, having, contain, require, include, provide, produce,
# Nearest to there: they, longer, it, these, considered, located, available, divided,
# Nearest to is: was, are, makes, becomes, includes, were, became, exists,
# Average loss at step 82000: 2.938131
# Average loss at step 84000: 2.895537
# Average loss at step 86000: 2.918567
# Average loss at step 88000: 2.942445
# Average loss at step 90000: 2.832739
# Nearest to all: many, some, various, every, both, animists, always, certain,
# Nearest to his: their, her, its, your, my, our, the, whose,
# Nearest to however: although, though, but, when, since, ean, hbo, unless,
# Nearest to known: regarded, referred, described, used, seen, classified, defined, called,
# Nearest to they: we, you, he, there, she, browed, outrun, imr,
# Nearest to state: government, justice, bayou, states, axiom, era, ennis, exertion,
# Nearest to in: during, since, on, throughout, within, of, outside, among,
# Nearest to UNK: liberated, es, giordano, carcasses, hesperides, socratic, typhus, quarterbacks,
# Nearest to been: become, occurred, fallen, be, come, begun, remained, grown,
# Nearest to most: many, some, more, less, especially, particularly, recapture, highly,
# Nearest to who: whom, tremble, lemass, young, gumby, equinoxes, plutonic, which,
# Nearest to by: via, through, interdisciplinarity, when, subvert, mayday, jozef, stoney,
# Nearest to such: well, follows, result, seen, known, far, simulates, opposed,
# Nearest to have: has, had, having, contain, require, produce, provide, allow,
# Nearest to there: they, it, longer, she, subsidized, considered, worth, handy,
# Nearest to is: was, remains, becomes, are, became, makes, includes, exists,
# Average loss at step 92000: 2.890650
# Average loss at step 94000: 2.888327
# Average loss at step 96000: 2.711174
# Average loss at step 98000: 2.464806
# Average loss at step 100000: 2.711290
# Nearest to all: every, many, both, various, several, any, some, certain,
# Nearest to his: their, her, its, s, your, my, the, our,
# Nearest to however: although, but, though, unless, despite, when, while, that,
# Nearest to known: regarded, referred, seen, described, defined, used, available, recognized,
# Nearest to they: we, you, he, there, she, i, these, unmodified,
# Nearest to state: justice, fanatic, government, snows, montparnasse, states, pissarro, suvs,
# Nearest to in: near, during, outside, within, inside, throughout, of, on,
# Nearest to UNK: che, occultism, bose, meisner, mindstorms, cornerstones, vogt, counterbalance,
# Nearest to been: become, occurred, fallen, come, begun, previously, existed, led,
# Nearest to most: more, many, particularly, some, less, best, highly, especially,
# Nearest to who: whom, young, tremble, whose, mischievous, which, equinoxes, typically,
# Nearest to by: through, via, strongly, among, subvert, jozef, trauma, from,
# Nearest to such: well, result, follows, seen, far, viewed, opposed, serve,
# Nearest to have: has, had, contain, having, require, produce, include, provide,
# Nearest to there: they, longer, it, he, worth, subsidized, divided, you,
# Nearest to is: was, makes, remains, exists, contains, becomes, provides, are,

# %%
num_points = 300

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                       ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
